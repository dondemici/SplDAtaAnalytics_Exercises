# %%
import pandas as pd

df = pd.read_csv('house_price.csv')
df.head()
# Out:
#    Id Neighborhood     HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0   1     Richmond         Duplex          4.0          5.0       1938
# 1   2        Delta         Duplex          7.0          1.0       1919
# 2   3      Burnaby  BasementSuite          4.0          6.0       1981
# 3   4       Surrey  BasementSuite          5.0          5.0       1932
# 4   5       Surrey       Detached          6.0          NaN       1957
#
#           YearRemodAdd  TotalBsmtSF    GrLivArea  FullBath  ...   Heating  \
# 0                 2007  1418.542110  1334.672273       2.0  ...  Electric
# 1 -9223372036854775808   570.622787   844.691015       1.0  ...  HeatPump
# 2                 1970   816.080798  2030.685080       1.0  ...   Radiant
# 3 -9223372036854775808   589.704590   625.410833       2.0  ...   Radiant
# 4                 1994  1052.067733  1427.795371       3.0  ...       Gas
#
#    Electrical  Foundation  Exterior1st  Exterior2nd  RoofStyle  SaleCondition  \
# ...
